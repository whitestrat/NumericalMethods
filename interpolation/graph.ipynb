# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Chebishev.csv", delimiter = ',', header = None)
data
# Out:
#            0         1          2         3         4         5          6  \
# 0   0.061558  0.000152   0.000000  0.000000  0.000000  0.828483   0.000000
# 1   0.544967  0.011833   0.526316  0.011040  0.526316  0.940930   0.526316
# 2   1.464466  0.083458   1.052632  0.043684  1.052632  1.038364   1.052632
# 3   2.730047  0.272933   1.578947  0.096602  1.578947  1.113716   1.578947
# 4   4.217828  0.587453   2.105263  0.167831  2.105263  1.160770   2.105263
# 5   5.782172  0.939456   2.631579  0.255044  2.631579  1.175208   2.631579
# 6   7.269952  1.154351   3.157895  0.355699  3.157895  1.155568   3.157895
# 7   8.535534  1.146906   3.684211  0.467019  3.684211  1.103752   3.684211
# 8   9.455032  1.027839   4.210526  0.585771  4.210526  1.024638   4.210526
# 9   9.938441  0.936894   4.736842  0.707932  4.736842  0.924199   4.736842
# 10       NaN       NaN   5.263158  0.828399 -0.000046  0.000000   5.263158
# ...

# %%
px = data[0]
py = data[1]

orx = data[2]
ory = data[3]

newton_x = data[4]
newton_y = data[5]

l_x = data[6]
l_y = data[7]

# %%
plt.scatter(px, py)
plt.plot(orx, ory)
plt.plot(l_x, l_y)
