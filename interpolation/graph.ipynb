# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Chebishev.csv", delimiter = ',', header = None)
data
# Out:
#            0         1          2         3          4         5          6  \
# 0   0.006852  0.000002   0.000000  0.000000   0.000000  0.000000   0.000000
# 1   0.061558  0.000152   0.101010  0.000408   0.101010  0.000408   0.101010
# 2   0.170371  0.001161   0.202020  0.001632   0.202020  0.001632   0.202020
# 3   0.332098  0.004405   0.303030  0.003669   0.303030  0.003669   0.303030
# 4   0.544967  0.011833   0.404040  0.006516   0.404040  0.006516   0.404040
# ..       ...       ...        ...       ...        ...       ...        ...
# 95       NaN       NaN   9.595960  1.002942   9.595960  1.003116   9.595960
# 96       NaN       NaN   9.696970  0.984230   9.696970  0.981141   9.696970
# 97       NaN       NaN   9.797979  0.964851   9.797979  0.966945   9.797979
# 98       NaN       NaN   9.898990  0.944858   9.898990  0.938116   9.898990
# 99       NaN       NaN  10.000000  0.924302  10.000000  0.929018  10.000000
#
#            7
# 0   0.000000
# 1   0.000408
# ...

# %%
px = data[0]
py = data[1]

orx = data[2]
ory = data[3]

n_x = data[4]
n_y = data[5]

l_x = data[6]
l_y = data[7]

# %%
plt.scatter(px, py)
plt.plot(orx, ory)
plt.plot(n_x, n_y)
